# %%
# !pip install ultralytics

# %% [markdown]
# **heatmap**

# %%
from ultralytics import YOLO
from ultralytics.solutions import heatmap
import cv2

model = YOLO("yolov8n.pt")   # YOLOv8 custom/pretrained model
cap = cv2.VideoCapture("/content/video.mp4")
assert cap.isOpened(), "Error reading video file"

# Heatmap Init
heatmap_obj = heatmap.Heatmap()
heatmap_obj.set_args(colormap=cv2.COLORMAP_CIVIDIS,
                     imw=cap.get(4),  # should same as im0 width
                     imh=cap.get(3),  # should same as im0 height
                     view_img=True)

# Video writer
video_writer = cv2.VideoWriter("heatmap_output1.avi",
                               cv2.VideoWriter_fourcc(*'mp4v'),
                               int(cap.get(5)),
                               (int(cap.get(3)), int(cap.get(4))))

classes_for_heatmap = [1,2,3]


while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        break
    results = model.track(im0, persist=True,classes=classes_for_heatmap)
    im0 = heatmap_obj.generate_heatmap(im0, tracks=results)
    video_writer.write(im0)

# %% [markdown]
# **YOLOv8-Region-Counter**

# %%
# !git clone https://github.com/ultralytics/ultralytics.git

# %%
# %cd /content/ultralytics/examples/YOLOv8-Region-Counter
# !python yolov8_region_counter.py --source "/content/video.mp4" --save-img
# Out:
# /content/ultralytics/examples/YOLOv8-Region-Counter
# ...
# 100% 6.23M/6.23M [00:00<00:00, 118MB/s]
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 30.6 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 5.4s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# 0: 384x640 1 car, 1 truck, 265.5ms
# Speed: 7.2ms preprocess, 265.5ms inference, 22.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 142.9ms
# Speed: 1.5ms preprocess, 142.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 1 truck, 145.1ms
# Speed: 1.5ms preprocess, 145.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 147.0ms
# Speed: 1.4ms preprocess, 147.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
